# %%
import requests
import json
import dotenv
import os
dotenv=dotenv.load_dotenv()

diff_api=os.getenv("diff_api")
url = "https://54285744-illusion-diffusion.gateway.alpha.fal.ai/"
payload = {
    "image_url": "https://storage.googleapis.com/falserverless/illusion-examples/checkers.png",
    "prompt": "(masterpiece:1.4), (best quality), (detailed), landscape, snowy mountains of northeast iran",
    "negative_prompt": "(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4), bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t"
}
# Status Code 401 - Unauthorized
headers = {
    "Authorization":diff_api ,
    "Content-Type": "application/json"
}
response = requests.post(url, json=payload, headers=headers)
response.status_code
response.json()
# Out:
# {'image': {'url': 'https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/github_54285744/419e74f289d04e108199d62e524aed13.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20240314%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240314T194946Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...',
#   'content_type': 'image/png',
#   'file_name': '419e74f289d04e108199d62e524aed13.png',
#   'file_size': 1557401,
#   'width': 1024,
#   'height': 1024},
#  'seed': 3560514820092868}
