# %%
# @title Default title text
import requests
import dotenv
import os
dotenv=dotenv.load_dotenv()
sdid_api=os.getenv("sdid_api")
url = "https://api.d-id.com/clips"
payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "en-US-JennyNeural"
        },
        "ssml": "false",
        "input": "are you kidding me? my hair is wonderful"
    },
    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } },
    "background": { "color": "false" },
    "presenter_id": "rian-lZC6MmWfC1"
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": sdid_api
}
response = requests.post(url, json=payload, headers=headers)
response.status_code
response.json()
# Out:
# {'id': 'clp_S5xqmKF7gsOXGiaW1W5f2',
#  'created_at': '2024-03-14T19:50:14.027Z',
#  'object': 'clip',
#  'status': 'created'}

# %%
url = "https://api.d-id.com/clips/clp_S5xqmKF7gsOXGiaW1W5f2"

headers = {
    "accept": "application/json",
    "authorization": sdid_api
}

response = requests.get(url, headers=headers)
response.status_code
response.json()
# Out:
# {'script': {'length': 40,
#   'ssml': False,
#   'subtitles': False,
#   'type': 'text',
#   'provider': {'type': 'microsoft', 'voice_id': 'en-US-JennyNeural'}},
#  'metadata': {'num_frames': 91,
#   'processing_fps': 22.448449971532405,
#   'resolution': [1080, 1080],
#   'size_kib': 6081.587890625},
#  'audio_url': 'https://d-id-clips-prod.s3.us-west-2.amazonaws.com/google-oauth2%7C112300326032520663606/clp_S5xqmKF7gsOXGiaW1W5f2/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIJ7CPKJNP&Expires=1710532214&Signature=%2FMDVeOFQnygPd3KQasY2AO5Apk4%3D',
#  'created_at': '2024-03-14T19:50:14.027Z',
#  'config': {'logo': {'url': 'https://d-id-user-logos-prod.s3.us-west-2.amazonaws.com/default/worker/did-watermark-2023.png',
#    'position': [0, 0]},
#   'result_format': '.mp4',
#   'fluent': False,
#   'motion_factor_kp': [1, 0.75]},
#  'source_url': 'https://clips-presenters.d-id.com/rian/lZC6MmWfC1/ibU83RPsbB/thumbnail.png',
#  'created_by': 'google-oauth2|112300326032520663606',
# ...
